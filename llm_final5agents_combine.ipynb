# %%
# ==============================================================================
# Sel 1: Instalasi & Impor Library Gabungan
# ==============================================================================
import os
import json
import pandas as pd
import time
import asyncio
import copy
import math
from typing import List, Dict, Any, Optional
from pathlib import Path
from datetime import date, datetime
from decimal import Decimal

# Third-party libraries
from dotenv import load_dotenv
import clickhouse_connect
from openai import AzureOpenAI

from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_aws import ChatBedrockConverse
from langchain_openai import AzureChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langsmith import Client

# Muat environment variables dari file .env
load_dotenv()
print("✅ Library dan environment variables siap.")


# ==============================================================================
# Sel 2: Konfigurasi Global
# ==============================================================================

# --- Database ClickHouse ---
CLICKHOUSE_HOST = os.getenv("CLICKHOUSE_HOST")
CLICKHOUSE_PORT = int(os.getenv("CLICKHOUSE_PORT", 18123))
CLICKHOUSE_USER = os.getenv("CLICKHOUSE_USER")
CLICKHOUSE_PASSWORD = os.getenv("CLICKHOUSE_PASSWORD")
CLICKHOUSE_DATABASE = os.getenv("CLICKHOUSE_DATABASE")

# --- Azure OpenAI (untuk pembuatan ringkasan) ---
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_KEY = os.getenv("AZURE_OPENAI_KEY")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")
AZURE_DEPLOYMENT_NAME = os.getenv("AZURE_DEPLOYMENT_NAME") 

# --- Langsmith (untuk tracing agent LLM) ---
os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING", "false")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY", "")
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT", "")
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT", "")

# --- Direktori & Grup Agent ---
DATA_DIR = Path("data")
PROMPT_DIR = Path("prompt")

AGENT_GROUPS = {
    "Consumables_and_Medical_Supplies": ["Consumables and Medical Supplies"],
    "Drugs": ["Drugs"],
    "Medical_Diagnostic": [
        "Laboratory", "Radiology", "Diagnostic",
        "Consultation and Visit", "Checkup Package"
    ],
    "Treatment_Facility": [
        "Surgeon", "Anesthetist", "Procedure and Therapy",
        "Procedure Room Rental", "Bed Rental", "Care Package"
    ],
    "Administrative_Others": [
        "Medical Equipment Rental", "Administrative Charge",
        "Other Service and Charge", "Other Items"
    ]
}

ORIGINAL_SALES_ITEM_TYPES = [
    'Consumables and Medical Supplies', 'Drugs', 'Laboratory', 'Other Items', 
    'Medical Equipment Rental', 'Radiology', 'Surgeon', 'Checkup Package', 
    'Consultation and Visit', 'Procedure Room Rental', 'Other Service and Charge', 
    'Diagnostic', 'Administrative Charge', 'Care Package', 'Anesthetist', 
    'Bed Rental', 'Procedure and Therapy'
]

print("✅ Konfigurasi global telah dimuat.")


# ==============================================================================
# Sel 3: Fungsi-Fungsi Pembantu (Gabungan dari kedua skrip)
# ==============================================================================

# --- Fungsi Koneksi & Setup ---

def setup_summary_llm() -> Optional[AzureOpenAI]:
    """Mengkonfigurasi dan mengembalikan client AzureOpenAI untuk ringkasan."""
    try:
        client = AzureOpenAI(
            azure_endpoint=AZURE_OPENAI_ENDPOINT,
            api_key=AZURE_OPENAI_KEY,
            api_version=AZURE_OPENAI_API_VERSION,
        )
        print("✅ Client Azure OpenAI (untuk ringkasan) berhasil dikonfigurasi.")
        return client
    except Exception as e:
        print(f"❌ Gagal mengkonfigurasi Azure OpenAI client: {e}")
        return None

def create_clickhouse_client() -> Optional[clickhouse_connect.driver.Client]:
    """Membuat dan mengembalikan koneksi client ke ClickHouse."""
    try:
        client = clickhouse_connect.get_client(
            host=CLICKHOUSE_HOST, port=CLICKHOUSE_PORT,
            username=CLICKHOUSE_USER, password=CLICKHOUSE_PASSWORD,
            database=CLICKHOUSE_DATABASE,
            connect_timeout=20,
        )
        client.command("SELECT 1")
        print("✅ Koneksi ke ClickHouse berhasil!")
        return client
    except Exception as e:
        print(f"❌ Gagal terkoneksi ke ClickHouse: {e}")
        return None

def get_agent_llm():
    """Factory untuk mendapatkan model LLM yang akan digunakan oleh agent."""
    provider = os.getenv("MODEL_PROVIDER", "gpt5").lower()
    if provider == "claude":
        return ChatBedrockConverse(model="anthropic.claude-3-sonnet-20240229-v1:0", temperature=0.0)
    elif provider == "gpt5":
        return AzureChatOpenAI(
            azure_endpoint=AZURE_OPENAI_ENDPOINT,
            api_key=AZURE_OPENAI_KEY,
            api_version=AZURE_OPENAI_API_VERSION,
            azure_deployment=AZURE_DEPLOYMENT_NAME,
            temperature=0.0
        )
    elif provider in ["gemini", "gemini15"]:
        model_name = "gemini-1.5-flash-latest" if provider == "gemini15" else "gemini-1.0-pro"
        return ChatGoogleGenerativeAI(model=model_name, temperature=0.0, convert_system_message_to_human=True)
    else:
        raise ValueError(f"Unknown MODEL_PROVIDER: {provider}")

# --- Fungsi Pemrosesan Data & Teks ---

def json_serializer(obj: Any) -> Any:
    """Konversi tipe data yang tidak didukung JSON."""
    if isinstance(obj, (datetime, date)):
        return obj.isoformat()
    if isinstance(obj, Decimal):
        return float(obj)
    raise TypeError(f"Tipe {type(obj)} tidak bisa diserialisasi ke JSON")

def load_json_data(file_path: Path) -> dict:
    """Memuat data dari file JSON."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError) as e:
        print(f"Error loading {file_path}: {e}")
        return {}

def generate_summary(client: AzureOpenAI, admission_data: Dict) -> str:
    """Membuat ringkasan medis dari data pasien menggunakan model Azure OpenAI."""
    if not client:
        return "Azure OpenAI client is not available."

    subjective_notes = "\n- ".join(admission_data.get('subjective', []))
    objective_notes = "\n- ".join(admission_data.get('objective', []))
    assessment_notes = "\n- ".join(admission_data.get('assessment', []))
    planning_notes = "\n- ".join(admission_data.get('planning', []))
    
    system_prompt = f"""
    You are a professional AI medical assistant. Your task is to create a clinical summary from the provided patient data.
    Your response MUST begin directly with the clinical summary. Do not include any conversational phrases.
    The summary must be in English and between 150-200 words.
    The summary should be professional, concise, and briefly explain the layman-friendly medical terms for the ICD-10 and ICD-9 codes and their correlation.

    --- Patient Data ---
    Disease Classification (ICD-10): {admission_data.get('disease', 'N/A')}
    Procedure Classification (ICD-9): {admission_data.get('procedure', 'N/A')}
    Subjective Notes (Patient Complaints):
    - {subjective_notes if subjective_notes else 'None.'}
    Objective Notes (Physical Examination):
    - {objective_notes if objective_notes else 'None.'}
    Assessment (Diagnosis):
    - {assessment_notes if assessment_notes else 'None.'}
    Planning (Actions):
    - {planning_notes if planning_notes else 'None.'}
    ---
    """
    
    try:
        response = client.chat.completions.create(
            model=AZURE_DEPLOYMENT_NAME, 
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": "Generate the clinical summary now."}
            ]
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error while creating summary with Azure OpenAI: {e}"

def fetch_soap_data(client: clickhouse_connect.driver.Client, admission_ids: List[int]) -> Dict[int, Dict[str, Any]]:
    """Mengambil data SOAP dari ClickHouse untuk daftar Admission ID."""
    if not admission_ids:
        return {}
    soap_query = """
    SELECT AdmissionId, groupArray(map('remark', remark, 'col_name', col_name)) AS soap
    FROM (
        SELECT DISTINCT AdmissionId, x.1 AS remark, x.2 AS col_name 
        FROM (
            SELECT AdmissionId, arrayJoin([
                (subjective_remarks, 'subjective'), (objective_remarks, 'objective'),
                (assessment_remarks, 'assessment'), (planning_remarks, 'planning')
            ]) AS x 
            FROM silver_siloam_etbs.soap_data 
            WHERE AdmissionId IN %(admission_ids)s
        ) WHERE x.1 IS NOT NULL AND trim(x.1) != ''
    ) GROUP BY AdmissionId
    """
    try:
        print(f"\n🚀 Mengambil data SOAP untuk {len(admission_ids)} admission(s)...")
        result = client.query(soap_query, parameters={"admission_ids": admission_ids})
        soap_results = {}
        for row in result.result_rows:
            admission_id, soap_data = row[0], row[1]
            restructured_soap = {'subjective': [], 'objective': [], 'assessment': [], 'planning': []}
            for item in soap_data:
                col_name, remark = item.get('col_name'), item.get('remark')
                if col_name in restructured_soap:
                    restructured_soap[col_name].append(remark)
            soap_results[admission_id] = restructured_soap
        print("✅ Data SOAP berhasil diambil dan direstrukturisasi.")
        return soap_results
    except Exception as e:
        print(f"❌ Error saat mengambil data SOAP: {e}")
        return {}
        
# --- Fungsi untuk Logika Agent ---
def transform_admission_record(record: dict) -> dict:
    """Mengubah format data mentah menjadi struktur yang lebih bersih."""
    items_list = [
        {"item_type": item.get("item_type"), "item_name": item.get("item_name"), "total_quantity": item.get("quantity")}
        for item in record.get('billing_data', {}).get('items', [])
    ]
    disease = record.get('disease')
    procedure = record.get('procedure')
    return {
        "AdmissionId": record.get("admission_id"), "AdmissionTypeName": record.get("admission_type"),
        "OrganizationCode": record.get("organization"), "Region": record.get("region"),
        "Archetype": record.get("archetype"), "PrimaryDoctor": record.get("doctor"),
        "Specialty": record.get("specialty"), "Sex": record.get("sex"),
        "BirthDate": record.get("birth_date"), "Age": record.get("age"),
        "AdmissionDate": record.get("admission_date"), "LengthOfStay": record.get("length_of_stay"),
        "PayerName": record.get("payer_name"), "PayerType": record.get("payer_type"),
        "DiseaseClassification": [disease] if disease else [], "ProcedureClassification": [procedure] if procedure else [],
        "summary": record.get("summary", "No clinical summary available."), "items": items_list
    }

def format_admission_context(admission: dict, relevant_item_types: list) -> str:
    """Memformat satu catatan admisi menjadi string konteks untuk LLM."""
    relevant_items = [item for item in admission.get("items", []) if item.get("item_type") in relevant_item_types]
    if relevant_items:
        items_str = "\n".join([f"- Item: {item.get('item_name', 'N/A')}, Quantity: {item.get('total_quantity', 0)}" for item in relevant_items])
    else:
        items_str = f"No items of types '{', '.join(relevant_item_types)}' were prescribed."

    icd10_str = ', '.join(admission.get('DiseaseClassification', [])) or '-'
    icd9_str = ', '.join(admission.get('ProcedureClassification', [])) or '-'

    return (
        f"--- Admission ID: {admission.get('AdmissionId', 'N/A')} ---\n"
        f"Payer Type: {admission.get('PayerType', 'N/A')}\n"
        f"ICD-10: {icd10_str}, ICD-9: {icd9_str}\n"
        f"Items Prescribed:\n{items_str}\n"
        f"Clinical Summary: {admission.get('summary', 'N/A')}\n"
    )

def get_full_context_for_group(item_types: list) -> str:
    """Mengkonsolidasikan konteks dari beberapa file JSON menjadi satu string besar."""
    full_context_list, processed_ids = [], set()
    for item_type in item_types:
        file_name = item_type.replace(' ', '_').replace('/', '-')
        data = load_json_data(DATA_DIR / f"{file_name}.json")
        for rec in data.get("data", {}).get("results", []):
            adm = transform_admission_record(rec)
            if adm.get("AdmissionId") not in processed_ids:
                full_context_list.append(format_admission_context(adm, item_types))
                processed_ids.add(adm.get("AdmissionId"))
    return "\n".join(full_context_list) if full_context_list else "No historical data available for this group."

def load_prompt_from_file(agent_name: str) -> str:
    """Memuat template prompt dari file .txt."""
    prompt_path = PROMPT_DIR / f"{agent_name}.txt"
    try:
        return prompt_path.read_text(encoding='utf-8')
    except Exception as e:
        print(f"Error loading prompt from {prompt_path}: {e}")
        return ""

print("✅ Fungsi pembantu siap digunakan.")


# ==============================================================================
# BAGIAN 1: PERSIAPAN DATA PENGETAHUAN (dari Skrip 1)
# ==============================================================================

def generate_knowledge_base(api_result_path: str, manual_admission_ids_to_exclude: List[int] = None) -> bool:
    """
    Fungsi ini menjalankan seluruh proses dari Skrip 1:
    1. Membaca data API sumber.
    2. Mengambil data SOAP dari ClickHouse.
    3. Menghasilkan ringkasan klinis untuk setiap data.
    4. Menyimpan hasilnya ke dalam file-file JSON di folder `data/`.
    """
    print("\n" + "="*50)
    print("BAGIAN 1: Memulai Pembuatan Knowledge Base")
    print("="*50)
    
    manual_admission_ids_to_exclude = manual_admission_ids_to_exclude or []
    # --- 1. Muat Data Sumber ---
    try:
        with open(f"{api_result_path}.json", "r", encoding="utf-8") as f:
            api_data = json.load(f)
        
        all_patients_data = api_data.get("data", {}).get("results", [])
        if not all_patients_data:
            print(f"⚠️ File '{api_result_path}.json' tidak berisi data pasien.")
            return False
    except Exception as e:
        print(f"❌ Error saat memuat '{api_result_path}.json': {e}")
        return False

    patients_data = [p for p in all_patients_data if p.get('admission_id') not in manual_admission_ids_to_exclude]
    print(f"✅ Data sumber dimuat. Jumlah data: {len(patients_data)}")

    # --- 2. Setup Koneksi ---
    ch_client = create_clickhouse_client()
    azure_client = setup_summary_llm()
    if not ch_client or not azure_client:
        print("⚠️ Proses pembuatan knowledge base dihentikan karena koneksi gagal.")
        return False

    # --- 3. Ambil Data SOAP & Gabungkan ---
    admission_ids = [p['admission_id'] for p in patients_data if 'admission_id' in p]
    all_soap_data = fetch_soap_data(ch_client, admission_ids)

    print("\n🤖 Memulai proses pembuatan ringkasan untuk data historis...")
    final_results_by_type = {item_type: [] for item_type in ORIGINAL_SALES_ITEM_TYPES}
    
    for i, patient in enumerate(patients_data):
        admission_id = patient.get('admission_id')
        if not admission_id:
            continue
        
        print(f"  ({i+1}/{len(patients_data)}) Membuat ringkasan untuk AdmissionId: {admission_id}...")
        patient_soap_data = all_soap_data.get(admission_id, {})
        data_for_llm = {**patient, **patient_soap_data}
        summary = generate_summary(azure_client, data_for_llm)
        time.sleep(1) # Rate limiting

        # Pisahkan data berdasarkan item_type
        for item_type in ORIGINAL_SALES_ITEM_TYPES:
            patient_copy = copy.deepcopy(patient)
            patient_copy['summary'] = summary
            if 'billing_data' in patient_copy and 'items' in patient_copy['billing_data']:
                filtered_items = [item for item in patient_copy['billing_data']['items'] if item.get('item_type') == item_type]
                patient_copy['billing_data']['items'] = filtered_items
                patient_copy['billing_data']['total_items'] = len(filtered_items)
            final_results_by_type[item_type].append(patient_copy)

    # --- 4. Simpan Hasil ke File JSON ---
    DATA_DIR.mkdir(exist_ok=True)
    for item_type, data in final_results_by_type.items():
        safe_filename = item_type.replace(" ", "_").replace("/", "-")
        output_path = DATA_DIR / f"{safe_filename}.json"
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump({"status": 1, "data": {"results": data}}, f, indent=4, default=json_serializer, ensure_ascii=False)
        print(f"✅ File knowledge base disimpan: {output_path}")
        
    print("\n🎉 Sukses! Knowledge base telah dibuat di dalam folder 'data/'.")
    return True

# ==============================================================================
# BAGIAN 2: ANALISIS PASIEN BARU (dari Skrip 2)
# ==============================================================================

def perform_item_analysis_for_groups():
    """Melakukan analisis statistik dan mengagregasinya berdasarkan grup agen."""
    print("\n--- Memulai Analisis Statistik Item dari Knowledge Base ---")
    analysis_string_per_group = {}
    average_items_per_group = {}
    individual_analysis, individual_averages = {}, {}

    for sit in ORIGINAL_SALES_ITEM_TYPES:
        file_name = sit.replace(' ', '_').replace('/', '-')
        data = load_json_data(DATA_DIR / f"{file_name}.json")
        admissions_raw = data.get("data", {}).get("results", [])
        
        items_for_this_type = []
        total_items, admission_count = 0, len(admissions_raw)

        if admissions_raw:
            for rec in admissions_raw:
                admission = transform_admission_record(rec)
                items = [item for item in admission.get("items", []) if item.get("item_type") == sit]
                total_items += len(items)
                items_for_this_type.extend([{"AdmissionId": admission["AdmissionId"], "item_name": item["item_name"], "Quantity": item["total_quantity"]} for item in items])

        individual_averages[sit] = math.ceil(total_items / admission_count) if admission_count > 0 else 0
        
        if items_for_this_type:
            items_df = pd.DataFrame(items_for_this_type).groupby('item_name').agg(
                frequency=('AdmissionId', 'nunique'),
                average_quantity=('Quantity', 'mean')
            ).reset_index().sort_values(by='frequency', ascending=False)
            individual_analysis[sit] = items_df.to_string()
        else:
            individual_analysis[sit] = f"No items found for detailed analysis for type: {sit}."

    for agent_name, item_types in AGENT_GROUPS.items():
        analysis_string_per_group[agent_name] = "\n\n".join([f"--- Analisis untuk {it} ---\n{individual_analysis.get(it, 'N/A')}" for it in item_types])
        average_items_per_group[agent_name] = sum(individual_averages.get(it, 0) for it in item_types)

    print("✅ Analisis statistik item per grup selesai.")
    return analysis_string_per_group, average_items_per_group
    
async def run_agent(agent_name: str, item_types: list, patient_info: dict, item_analysis_str: str, avg_items_analysis_str: str):
    """Menjalankan satu agent LLM untuk melakukan prediksi."""
    print(f"🚀 Agent [{agent_name}] memulai...")
    template_str = load_prompt_from_file(agent_name)
    if not template_str:
        return {agent_name: {"error": "Prompt file missing or empty."}}

    prompt = PromptTemplate.from_template(template_str)
    full_context_str = get_full_context_for_group(item_types)
    llm = get_agent_llm()
    parser = JsonOutputParser()
    chain = prompt | llm | parser

    try:
        patient_info_str = "\n".join([f"{key}: {value}" for key, value in patient_info.items()])
        
        input_data = {
            "item_analysis": item_analysis_str,
            "average_items_analysis": avg_items_analysis_str,
            "context": full_context_str,
            "patient_info": patient_info_str,
            "sales_item_type": agent_name
        }
        result_json = await chain.ainvoke(input_data, config={"tags": [agent_name]})
        print(f"✅ Agent [{agent_name}] selesai.")
        return {agent_name: result_json}
    except Exception as e:
        print(f"❌ Agent [{agent_name}] gagal: {e}")
        return {agent_name: {"error": str(e)}}

async def run_all_agents(patient_info: dict, item_analysis_per_group: dict, avg_items_per_group: dict):
    """Menjalankan semua agent secara paralel."""
    print("\n" + "="*50)
    print("BAGIAN 2: Memulai Analisis Pasien Baru dengan Agents")
    print("="*50)

    tasks = [
        run_agent(
            agent_name,
            item_types,
            patient_info,
            item_analysis_per_group.get(agent_name, "No analysis available."),
            f"Total average number of items for '{agent_name}' category: {avg_items_per_group.get(agent_name, 0)}"
        )
        for agent_name, item_types in AGENT_GROUPS.items()
    ]
    results = await asyncio.gather(*tasks)
    final_result = {}
    for res in results:
        final_result.update(res)
    return final_result


# ==============================================================================
# FUNGSI UTAMA (MAIN ORCHESTRATOR)
# ==============================================================================

async def main():
    """Fungsi utama untuk menjalankan seluruh alur kerja."""
    
    # --- Langkah 0: Setup Awal ---
    DATA_DIR.mkdir(exist_ok=True)
    PROMPT_DIR.mkdir(exist_ok=True)
    # Inisialisasi Langsmith client
    client = Client()
        # --- LANGKAH 3: Definisikan Data Pasien Baru ---
    # Data pasien baru ini akan dianalisis TANPA membuat ringkasan baru
    patient_input = {
    "hospital_code": "SHMK",
    "archetype": "Premium Generalist",
    "hospital_region": "Region 4",
    "birthdate": "2001-09-12",
    "gender": "Female",
    "icd10": [
      "K01.1"
    ],
    "icd9": [
      "23.19"
    ],
    "primary_doctor": "drg. Timurwati, SpBM",
    "primary_doctor_id": 9000000002001,
    "doctor_specialty": "DENTISTRY - ORAL AND MAXILLOFACIAL SURGERY",
    "admission_type": "Inpatient",
    "admission_id": -2023065,
    "admission_date": "2024-12-10 15:21:45",
    "discharge_date": "",
    "anesthesia_doctor": "",
    "anesthesia_type": "",
    "surgery_nature": "",
    "payer_type": "Third Parties - Insurance Government (BPJS)",
    "payer_name": "BPJS KESEHATAN",
    "payer_id": 14000000002601,
  }
    

    # --- LANGKAH 1: Buat atau verifikasi Knowledge Base ---
    success = generate_knowledge_base('api_result',[patient_input.get("admission_id")])
    if not success:
        print("\nProses dihentikan karena pembuatan knowledge base gagal.")
        return

    # --- LANGKAH 2: Analisis Statistik pada Knowledge Base ---
    item_analysis_per_group_dict, average_items_per_group_dict = perform_item_analysis_for_groups()
    

    # --- LANGKAH 4: Jalankan Agents untuk Prediksi ---
    final_predictions = await run_all_agents(patient_input, item_analysis_per_group_dict, average_items_per_group_dict)
    
    # --- LANGKAH 5: Tampilkan Hasil ---
    print("\n\n--- Raw JSON Output ---")
    print(json.dumps(final_predictions, indent=2))

    print("\n\n--- Tabel Prediksi Akhir ---")
    table_data = []
    for agent_group, details in final_predictions.items():
        if isinstance(details, dict) and 'predictions' in details:
            for pred in details.get('predictions', []):
                table_data.append({
                    "Agent Group": agent_group,
                    "Item Name": pred.get('item', 'N/A'),
                    "Quantity": pred.get('quantity', 0),
                    "Reasoning": next((r['reason'] for r in details.get('reasoning', []) if r.get('item') == pred.get('item')), 'N/A'),
                })
        else:
            table_data.append({"Agent Group": agent_group, "Item Name": f"Error: {details.get('error', 'Unknown')}", "Quantity": 0, "Reasoning": "N/A"})
            
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 200)
    pd.set_option('display.max_colwidth', 60)
    global predictions_df
    predictions_df = pd.DataFrame(table_data)
    print(predictions_df)

    # ==============================================================================
    # LANGKAH 6 : Pembersihan File Knowledge Base Setelah Prediksi Selesai
    # ==============================================================================
    print("\n\n--- Memulai Pembersihan Knowledge Base ---")
    try:
        # Mencari semua file dengan ekstensi .json di dalam direktori DATA_DIR
        json_files_to_delete = list(DATA_DIR.glob('*.json'))
        
        if not json_files_to_delete:
            print("Tidak ada file .json yang ditemukan di folder 'data/' untuk dihapus.")
        else:
            for file_path in json_files_to_delete:
                file_path.unlink()  # Menghapus file
                print(f"✅ File sementara dihapus: {file_path}")
        
        print("🎉 Pembersihan file knowledge base selesai.")
    except Exception as e:
        print(f"❌ Terjadi error saat membersihkan file di folder 'data/': {e}")



if __name__ == "__main__":
    #asyncio.run(main())
    await main()
# Out:
# ✅ Library dan environment variables siap.
# ✅ Konfigurasi global telah dimuat.
# ✅ Fungsi pembantu siap digunakan.
#
# ==================================================
# BAGIAN 1: Memulai Pembuatan Knowledge Base
# ==================================================
# ✅ Data sumber dimuat. Jumlah data: 10
# ✅ Koneksi ke ClickHouse berhasil!
# ✅ Client Azure OpenAI (untuk ringkasan) berhasil dikonfigurasi.
#
# 🚀 Mengambil data SOAP untuk 10 admission(s)...
# ✅ Data SOAP berhasil diambil dan direstrukturisasi.
#
# 🤖 Memulai proses pembuatan ringkasan untuk data historis...
#   (1/10) Membuat ringkasan untuk AdmissionId: -2004234...
#   (2/10) Membuat ringkasan untuk AdmissionId: -3152391...
#   (3/10) Membuat ringkasan untuk AdmissionId: 9000007046318...
#   (4/10) Membuat ringkasan untuk AdmissionId: 9000007038123...
#   (5/10) Membuat ringkasan untuk AdmissionId: 9000007035801...
#   (6/10) Membuat ringkasan untuk AdmissionId: -4167019...
#   (7/10) Membuat ringkasan untuk AdmissionId: -4503356...
#   (8/10) Membuat ringkasan untuk AdmissionId: 9000006952302...
#   (9/10) Membuat ringkasan untuk AdmissionId: -4733119...
#   (10/10) Membuat ringkasan untuk AdmissionId: 9000006935505...
# ✅ File knowledge base disimpan: data/Consumables_and_Medical_Supplies.json
# ✅ File knowledge base disimpan: data/Drugs.json
# ✅ File knowledge base disimpan: data/Laboratory.json
# ✅ File knowledge base disimpan: data/Other_Items.json
# ✅ File knowledge base disimpan: data/Medical_Equipment_Rental.json
# ✅ File knowledge base disimpan: data/Radiology.json
# ✅ File knowledge base disimpan: data/Surgeon.json
# ✅ File knowledge base disimpan: data/Checkup_Package.json
# ✅ File knowledge base disimpan: data/Consultation_and_Visit.json
# ✅ File knowledge base disimpan: data/Procedure_Room_Rental.json
# ✅ File knowledge base disimpan: data/Other_Service_and_Charge.json
# ✅ File knowledge base disimpan: data/Diagnostic.json
# ✅ File knowledge base disimpan: data/Administrative_Charge.json
# ✅ File knowledge base disimpan: data/Care_Package.json
# ✅ File knowledge base disimpan: data/Anesthetist.json
# ✅ File knowledge base disimpan: data/Bed_Rental.json
# ✅ File knowledge base disimpan: data/Procedure_and_Therapy.json
#
# 🎉 Sukses! Knowledge base telah dibuat di dalam folder 'data/'.
#
# --- Memulai Analisis Statistik Item dari Knowledge Base ---
# ✅ Analisis statistik item per grup selesai.
#
# ==================================================
# BAGIAN 2: Memulai Analisis Pasien Baru dengan Agents
# ==================================================
# 🚀 Agent [Consumables_and_Medical_Supplies] memulai...
# 🚀 Agent [Drugs] memulai...
# 🚀 Agent [Medical_Diagnostic] memulai...
# 🚀 Agent [Treatment_Facility] memulai...
# 🚀 Agent [Administrative_Others] memulai...
# ✅ Agent [Administrative_Others] selesai.
# ✅ Agent [Medical_Diagnostic] selesai.
# ✅ Agent [Treatment_Facility] selesai.
# ✅ Agent [Drugs] selesai.
# ✅ Agent [Consumables_and_Medical_Supplies] selesai.
#
#
# --- Raw JSON Output ---
# {
#   "Consumables_and_Medical_Supplies": {
#     "predictions": [
#       {
#         "item": "VIOREX 2% 20ML (REPACK)",
#         "quantity": 1
#       },
#       {
#         "item": "MEDIGLOVES STERILE POWDER FREE LATEX 6.5 ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "SYRINGE WITHOUT NEEDLE LUER LOCK 20ML KANGJIN",
#         "quantity": 1
#       },
#       {
#         "item": "SUCTION CATH 12CH SHM-SC-12SCC HOSPITECH",
#         "quantity": 1
#       },
#       {
#         "item": "SURFLO IV CATH 18GX1.1/4INCH SR+OX1832C3 TERUMO",
#         "quantity": 1
#       },
#       {
#         "item": "ADULT BACTERIAL VIRAL FILTER WITH HME LUER LOCK PORT (VENTICAIRE) 038-41-355 FLEXICARE",
#         "quantity": 1
#       },
#       {
#         "item": "TRUSYNTH 3-0 90CM ROUND BODIED 26MM VIOLET 10F90DZ26 HEALTHIUM",
#         "quantity": 1
#       },
#       {
#         "item": "TRANSPARANT FILM DRESSING 6X7CM WITH NOTCH 1IVD-0607N WINNER",
#         "quantity": 1
#       },
#       {
#         "item": "INFUSION SET 21GX1.5INCH ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "SYRINGE 5ML (22Gx1.5INCH) ONEMED",
#         "quantity": 2
#       },
#       {
#         "item": "SYRINGE 10ML (21Gx1.5INCH) ONEMED",
#         "quantity": 2
#       },
#       {
#         "item": "ALCOHOL SWABS ONEMED",
#         "quantity": 10
#       },
#       {
#         "item": "APRON PLASTIK LENGAN PENDEK ONEMED",
#         "quantity": 3
#       },
#       {
#         "item": "js/ INSYTE TM IV CATHETER 20GA X 1.16 IN (1,1 X 30MM) 381234 BD",
#         "quantity": 1
#       },
#       {
#         "item": "js/ SUCTION CONNECTING TUBE 3.6M 4815000047 ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "ECG ELECTRODES BLUESENSOR R-00-S/25 AMBU",
#         "quantity": 3
#       },
#       {
#         "item": "NEEDLE 18Gx1.5MM ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "GUEDEL AIRWAY 4/90MM STERILE; 900 0090 1; BICAKCILAR",
#         "quantity": 1
#       },
#       {
#         "item": "MEDIGLOVES STERILE POWDER FREE LATEX 7.0 ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "T-HEMOCEL 5X7,5CM ORC-01 TRITON",
#         "quantity": 1
#       },
#       {
#         "item": "STERILE SCALPEL BLADES NO. 15 110-115 HEINZ HERENZ",
#         "quantity": 1
#       },
#       {
#         "item": "js/ UNDERPAD 60X90 91711 SENSI",
#         "quantity": 1
#       },
#       {
#         "item": "SYRINGE 3ML (23Gx1.25INCH) ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "3WAY STOPCOCK WITH EXTENSION TUBE GP CARE",
#         "quantity": 1
#       },
#       {
#         "item": "MEDIGLOVES STERILE POWDER FREE LATEX 7.5 ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "js/ INSYTE TM IV CATHETER 22GAx1.00INCH 381223 BD",
#         "quantity": 1
#       },
#       {
#         "item": "PD ETT NON KK CUFFED 7.0MM; 104105; PRODEVICE",
#         "quantity": 1
#       },
#       {
#         "item": "KASSA STERILE LD 7.5CM X 7.5CM 16PLY @5S 7165LD ONEMED",
#         "quantity": 3
#       },
#       {
#         "item": "SYRINGE WITH NEEDLE 23G LUER LOCK 3ML KANGJIN",
#         "quantity": 1
#       },
#       {
#         "item": "ETT CUFFED NO.7.0 SPIRAL 55170701 BICAKCILAR",
#         "quantity": 1
#       },
#       {
#         "item": "TRANSOFIX 4090500 BBRAUN",
#         "quantity": 1
#       },
#       {
#         "item": "HANSAPLAST",
#         "quantity": 3
#       },
#       {
#         "item": "PLESTERIN KAIN ELASTIS; ONEMED",
#         "quantity": 3
#       },
#       {
#         "item": "LYOSTYPT 5 X 8CM 1069152 BBRAUN",
#         "quantity": 1
#       },
#       {
#         "item": "SUCTION CONNECTING TUBE 3.6M PLUS YANKAUER TIP ONEMED",
#         "quantity": 1
#       },
#       {
#         "item": "SYRINGE 10ML SS+10L2138 TERUMO",
#         "quantity": 1
#       }
#     ],
#     "references": [
#       -2004234,
#       -3152391,
#       9000007046318,
#       9000007038123,
#       9000007035801,
#       -4167019,
#       -4503356,
#       9000006952302,
#       -4733119,
#       9000006935505
#     ],
#     "reasoning": [
#       {
#         "item": "VIOREX 2% 20ML (REPACK)",
#         "analysis": "Topical antiseptic solution used for preoperative skin preparation and wound cleaning.",
#         "reason": "Appears in all similar admissions (10/10); essential for surgical site antisepsis in odontectomy."
#       },
#       {
#         "item": "MEDIGLOVES STERILE POWDER FREE LATEX 6.5 ONEMED",
#         "analysis": "Sterile gloves for maintaining aseptic technique during surgery.",
#         "reason": "High frequency (10/10 admissions); critical for infection control."
#       },
#       {
#         "item": "SYRINGE WITHOUT NEEDLE LUER LOCK 20ML KANGJIN",
#         "analysis": "Used for irrigation or medication administration during and after surgery.",
#         "reason": "High frequency (10/10 admissions); standard in dental surgical procedures."
#       },
#       {
#         "item": "SUCTION CATH 12CH SHM-SC-12SCC HOSPITECH",
#         "analysis": "Used to remove blood, saliva, and debris from the surgical field.",
#         "reason": "High frequency (10/10 admissions); essential for maintaining clear operative field."
#       },
#       {
#         "item": "SURFLO IV CATH 18GX1.1/4INCH SR+OX1832C3 TERUMO",
#         "analysis": "Peripheral IV catheter for fluid and medication administration.",
#         "reason": "High frequency (10/10 admissions); required for anesthesia and perioperative care."
#       },
#       {
#         "item": "ADULT BACTERIAL VIRAL FILTER WITH HME LUER LOCK PORT (VENTICAIRE) 038-41-355 FLEXICARE",
#         "analysis": "Airway filter to prevent cross-contamination during anesthesia.",
#         "reason": "High frequency (9/10 admissions); standard in general anesthesia cases."
#       },
#       {
#         "item": "TRUSYNTH 3-0 90CM ROUND BODIED 26MM VIOLET 10F90DZ26 HEALTHIUM",
#         "analysis": "Absorbable suture for closing surgical wounds in oral cavity.",
#         "reason": "High frequency (9/10 admissions); essential for odontectomy wound closure."
#       },
#       {
#         "item": "TRANSPARANT FILM DRESSING 6X7CM WITH NOTCH 1IVD-0607N WINNER",
#         "analysis": "Protective dressing for IV sites or small wounds.",
#         "reason": "High frequency (9/10 admissions); used to secure IV lines postoperatively."
#       },
#       {
#         "item": "INFUSION SET 21GX1.5INCH ONEMED",
#         "analysis": "Used for IV fluid and medication administration.",
#         "reason": "High frequency (9/10 admissions); standard perioperative supply."
#       },
#       {
#         "item": "SYRINGE 5ML (22Gx1.5INCH) ONEMED",
#         "analysis": "For injection of medications such as analgesics or antiemetics.",
#         "reason": "High frequency (9/10 admissions); dosage based on average use."
#       },
#       {
#         "item": "SYRINGE 10ML (21Gx1.5INCH) ONEMED",
#         "analysis": "For IV medication administration or flushing lines.",
#         "reason": "High frequency (9/10 admissions); quantity based on median usage."
#       },
#       {
#         "item": "ALCOHOL SWABS ONEMED",
#         "analysis": "Used for skin antisepsis before injections or IV insertions.",
#         "reason": "High frequency (8/10 admissions); quantity standardized at 10."
#       },
#       {
#         "item": "APRON PLASTIK LENGAN PENDEK ONEMED",
#         "analysis": "Protective barrier for surgical team during procedures.",
#         "reason": "High frequency (8/10 admissions); standard PPE in oral surgery."
#       },
#       {
#         "item": "js/ INSYTE TM IV CATHETER 20GA X 1.16 IN (1,1 X 30MM) 381234 BD",
#         "analysis": "Peripheral IV catheter for fluid/medication administration.",
#         "reason": "High frequency (8/10 admissions); alternative gauge for IV access."
#       },
#       {
#         "item": "js/ SUCTION CONNECTING TUBE 3.6M 4815000047 ONEMED",
#         "analysis": "Connects suction device to catheter for fluid removal.",
#         "reason": "High frequency (7/10 admissions); essential for maintaining clear surgical field."
#       },
#       {
#         "item": "ECG ELECTRODES BLUESENSOR R-00-S/25 AMBU",
#         "analysis": "Used for intraoperative cardiac monitoring.",
#         "reason": "High frequency (7/10 admissions); quantity based on average use."
#       },
#       {
#         "item": "NEEDLE 18Gx1.5MM ONEMED",
#         "analysis": "Used for drawing up or administering medications.",
#         "reason": "High frequency (7/10 admissions); standard perioperative supply."
#       },
#       {
#         "item": "GUEDEL AIRWAY 4/90MM STERILE; 900 0090 1; BICAKCILAR",
#         "analysis": "Airway adjunct to maintain patency during anesthesia.",
#         "reason": "High frequency (7/10 admissions); standard in general anesthesia."
#       },
#       {
#         "item": "MEDIGLOVES STERILE POWDER FREE LATEX 7.0 ONEMED",
#         "analysis": "Sterile gloves for surgical team.",
#         "reason": "High frequency (7/10 admissions); size variation for staff."
#       },
#       {
#         "item": "T-HEMOCEL 5X7,5CM ORC-01 TRITON",
#         "analysis": "Hemostatic agent to control bleeding.",
#         "reason": "High frequency (7/10 admissions); essential in oral surgery."
#       },
#       {
#         "item": "STERILE SCALPEL BLADES NO. 15 110-115 HEINZ HERENZ",
#         "analysis": "Used for precise surgical incisions.",
#         "reason": "High frequency (6/10 admissions); standard for odontectomy."
#       },
#       {
#         "item": "js/ UNDERPAD 60X90 91711 SENSI",
#         "analysis": "Absorbent pad to protect surfaces from fluids.",
#         "reason": "High frequency (6/10 admissions); standard in surgical settings."
#       },
#       {
#         "item": "SYRINGE 3ML (23Gx1.25INCH) ONEMED",
#         "analysis": "For small volume injections.",
#         "reason": "High frequency (6/10 admissions); used for local anesthetics or small doses."
#       },
#       {
#         "item": "3WAY STOPCOCK WITH EXTENSION TUBE GP CARE",
#         "analysis": "Allows multiple IV lines or medication ports.",
#         "reason": "High frequency (6/10 admissions); essential for perioperative IV management."
#       },
#       {
#         "item": "MEDIGLOVES STERILE POWDER FREE LATEX 7.5 ONEMED",
#         "analysis": "Sterile gloves for surgical team.",
#         "reason": "High frequency (6/10 admissions); size variation for staff."
#       },
#       {
#         "item": "js/ INSYTE TM IV CATHETER 22GAx1.00INCH 381223 BD",
#         "analysis": "Peripheral IV catheter for smaller veins.",
#         "reason": "High frequency (5/10 admissions); alternative gauge for IV access."
#       },
#       {
#         "item": "PD ETT NON KK CUFFED 7.0MM; 104105; PRODEVICE",
#         "analysis": "Endotracheal tube for airway management during anesthesia.",
#         "reason": "Moderate frequency (5/10 admissions); relevant for general anesthesia cases."
#       },
#       {
#         "item": "KASSA STERILE LD 7.5CM X 7.5CM 16PLY @5S 7165LD ONEMED",
#         "analysis": "Sterile gauze for wound dressing and bleeding control.",
#         "reason": "Moderate frequency (5/10 admissions); essential for oral surgery."
#       },
#       {
#         "item": "SYRINGE WITH NEEDLE 23G LUER LOCK 3ML KANGJIN",
#         "analysis": "For precise medication administration.",
#         "reason": "Moderate frequency (4/10 admissions); relevant for perioperative injections."
#       },
#       {
#         "item": "ETT CUFFED NO.7.0 SPIRAL 55170701 BICAKCILAR",
#         "analysis": "Endotracheal tube for airway management.",
#         "reason": "Moderate frequency (4/10 admissions); alternative to non-cuffed tube."
#       },
#       {
#         "item": "TRANSOFIX 4090500 BBRAUN",
#         "analysis": "IV connector for secure fluid administration.",
#         "reason": "Moderate frequency (4/10 admissions); standard in surgical IV setups."
#       },
#       {
#         "item": "HANSAPLAST",
#         "analysis": "Adhesive bandage for minor wound coverage.",
#         "reason": "Moderate frequency (4/10 admissions); used post-IV removal."
#       },
#       {
#         "item": "PLESTERIN KAIN ELASTIS; ONEMED",
#         "analysis": "Elastic adhesive bandage for securing dressings.",
#         "reason": "Moderate frequency (3/10 admissions); relevant for postoperative care."
#       },
#       {
#         "item": "LYOSTYPT 5 X 8CM 1069152 BBRAUN",
#         "analysis": "Hemostatic sponge for bleeding control.",
#         "reason": "Lower frequency (2/10 admissions) but clinically relevant for oral surgery."
#       },
#       {
#         "item": "SUCTION CONNECTING TUBE 3.6M PLUS YANKAUER TIP ONEMED",
#         "analysis": "Rigid suction tip for oral cavity fluid removal.",
#         "reason": "Lower frequency (2/10 admissions) but relevant for maintaining clear surgical field."
#       },
#       {
#         "item": "SYRINGE 10ML SS+10L2138 TERUMO",
#         "analysis": "High-quality syringe for precise medication administration.",
#         "reason": "Lower frequency (2/10 admissions) but relevant for anesthesia and medication delivery."
#       }
#     ],
#     "Item Average": 36,
#     "Summary": "The new patient is a 23-year-old female diagnosed with ICD-10 K01.1 (impacted teeth) and ICD-9 23.19 (other surgical extraction of tooth), undergoing odontectomy under general anesthesia. This is a standard oral and maxillofacial surgical case with low complication risk. Based on analysis of 10 highly similar past admissions, the predicted consumables and medical supplies list includes high-frequency global items (appearing in \u22654 admissions) and clinically essential items for odontectomy. The average number of items in similar admissions is 36, which is used as the prediction target. Items include surgical disposables (gloves, gauze, sutures, scalpels), airway and anesthesia equipment (ETT, airway adjuncts, filters), IV access and fluid administration sets, suction equipment, antiseptics, and wound dressings. This ensures aseptic technique, effective anesthesia, hemostasis, and postoperative wound care."
#   },
#   "Drugs": {
#     "predictions": [
#       {
#         "item": "CEFIXIME 200MG CAP",
#         "quantity": 10
#       },
#       {
#         "item": "CEFTRIAXONE 1GRAM INJ",
#         "quantity": 1
#       },
#       {
#         "item": "js/ FENTANYL 0,05MG/ML-2ML INJ",
#         "quantity": 2
#       },
#       {
#         "item": "ROCUM 1% 5ML INJ",
#         "quantity": 1
#       },
#       {
#         "item": "ONDANSETRON 4MG/2ML INJ",
#         "quantity": 1
#       },
#       {
#         "item": "OMEPRAZOLE 20MG CAP",
#         "quantity": 10
#       },
#       {
#         "item": "DEXAMETHASONE 5MG/ML-1ML INJ",
#         "quantity": 3
#       },
#       {
#         "item": "RECOFOL N 1% 10MG/ML-20ML INJ",
#         "quantity": 1
#       },
#       {
#         "item": "ESOMEPRAZOLE 40MG INJ",
#         "quantity": 1
#       },
#       {
#         "item": "KETOROLAC 30MG/ML-1ML INJ",
#         "quantity": 3
#       },
#       {
#         "item": "ATROPINE 0,25MG/ML-1ML INJ",
#         "quantity": 4
#       },
#       {
#         "item": "ASAM TRANEKSAMAT 100MG/ML-5ML INJ",
#         "quantity": 1
#       },
#       {
#         "item": "NEOSTIGMINE METHYLSULFATE 0,5MG/ML INJ",
#         "quantity": 4
#       },
#       {
#         "item": "js/ POVIDONE IODINE 60ML SOL",
#         "quantity": 1
#       },
#       {
#         "item": "GENTAMYCIN 40MG/ML-2ML INJ",
#         "quantity": 2
#       },
#       {
#         "item": "IBUPROFEN 400MG TAB",
#         "quantity": 10
#       },
#       {
#         "item": "RINGER LACTATE 500ML INF (BBRAUN)",
#         "quantity": 2
#       },
#       {
#         "item": "PEHACAIN 2ML INJ",
#         "quantity": 3
#       },
#       {
#         "item": "DEXAMETHASONE 0,5MG TAB",
#         "quantity": 10
#       },
#       {
#         "item": "WATER FOR INJ 25ML (OTSU)",
#         "quantity": 1
#       },
#       {
#         "item": "SEVOFLURANE 250ML",
#         "quantity": 40
#       },
#       {
#         "item": "NATRIUM DIKLOFENAK 50MG TAB",
#         "quantity": 10
#       },
#       {
#         "item": "PARACETAMOL 10MG/ML-100ML INF",
#         "quantity": 1
#       },
#       {
#         "item": "OTSU-NS NACL 0,9% 500ML INF",
#         "quantity": 1
#       },
#       {
#         "item": "SEDACUM 5MG/5ML INJ",
#         "quantity": 1
#       },
#       {
#         "item": "SAGESTAM 40MG/ML INJ",
#         "quantity": 2
#       },
#       {
#         "item": "EMBALASE",
#         "quantity": 1
#       }
#     ],
#     "references": [
#       -2004234,
#       -3152391,
#       9000007046318,
#       9000007038123,
#       9000007035801,
#       -4167019,
#       -4503356,
#       9000006952302,
#       -4733119,
#       9000006935505
#     ],
#     "reasoning": [
#       {
#         "item": "CEFIXIME 200MG CAP",
#         "analysis": "Oral third-generation cephalosporin antibiotic for postoperative infection prophylaxis in dental surgery.",
#         "reason": "High frequency (10/10 admissions) in similar odontectomy cases; standard oral antibiotic post-discharge."
#       },
#       {
#         "item": "CEFTRIAXONE 1GRAM INJ",
#         "analysis": "Broad-spectrum cephalosporin antibiotic for perioperative infection prevention.",
#         "reason": "Universal use in similar cases for IV prophylaxis; dosage matches average."
#       },
#       {
#         "item": "js/ FENTANYL 0,05MG/ML-2ML INJ",
#         "analysis": "Potent opioid analgesic for intraoperative and immediate postoperative pain control.",
#         "reason": "Present in all matched admissions; essential for anesthesia protocol."
#       },
#       {
#         "item": "ROCUM 1% 5ML INJ",
#         "analysis": "Neuromuscular blocking agent (rocuronium) for muscle relaxation during general anesthesia.",
#         "reason": "Used in all similar surgical cases; standard anesthesia induction agent."
#       },
#       {
#         "item": "ONDANSETRON 4MG/2ML INJ",
#         "analysis": "5-HT3 antagonist antiemetic to prevent postoperative nausea and vomiting.",
#         "reason": "High frequency (10/10 admissions); standard prophylaxis in general anesthesia."
#       },
#       {
#         "item": "OMEPRAZOLE 20MG CAP",
#         "analysis": "Proton pump inhibitor to reduce gastric acid and prevent stress ulcers.",
#         "reason": "High frequency (10/10 admissions); standard perioperative gastric protection."
#       },
#       {
#         "item": "DEXAMETHASONE 5MG/ML-1ML INJ",
#         "analysis": "Corticosteroid for reducing postoperative inflammation and swelling.",
#         "reason": "High frequency (9/10 admissions); dosage matches average."
#       },
#       {
#         "item": "RECOFOL N 1% 10MG/ML-20ML INJ",
#         "analysis": "Propofol-based general anesthetic for induction and maintenance.",
#         "reason": "High frequency (9/10 admissions); essential for anesthesia."
#       },
#       {
#         "item": "ESOMEPRAZOLE 40MG INJ",
#         "analysis": "IV proton pump inhibitor for gastric acid suppression perioperatively.",
#         "reason": "High frequency (9/10 admissions); used when oral route not possible."
#       },
#       {
#         "item": "KETOROLAC 30MG/ML-1ML INJ",
#         "analysis": "NSAID analgesic for moderate postoperative pain.",
#         "reason": "High frequency (8/10 admissions); standard non-opioid analgesic."
#       },
#       {
#         "item": "ATROPINE 0,25MG/ML-1ML INJ",
#         "analysis": "Anticholinergic to reduce secretions and prevent bradycardia during anesthesia.",
#         "reason": "High frequency (8/10 admissions); standard anesthesia adjunct."
#       },
#       {
#         "item": "ASAM TRANEKSAMAT 100MG/ML-5ML INJ",
#         "analysis": "Antifibrinolytic to reduce perioperative bleeding.",
#         "reason": "High frequency (7/10 admissions); indicated in oral surgery."
#       },
#       {
#         "item": "NEOSTIGMINE METHYLSULFATE 0,5MG/ML INJ",
#         "analysis": "Reversal agent for neuromuscular blockade post-surgery.",
#         "reason": "High frequency (7/10 admissions); standard anesthesia reversal."
#       },
#       {
#         "item": "js/ POVIDONE IODINE 60ML SOL",
#         "analysis": "Topical antiseptic for surgical site disinfection.",
#         "reason": "High frequency (7/10 admissions); essential for oral surgery wound care."
#       },
#       {
#         "item": "GENTAMYCIN 40MG/ML-2ML INJ",
#         "analysis": "Aminoglycoside antibiotic for additional gram-negative coverage.",
#         "reason": "High frequency (7/10 admissions); used in combination with ceftriaxone."
#       },
#       {
#         "item": "IBUPROFEN 400MG TAB",
#         "analysis": "NSAID for postoperative pain and inflammation control.",
#         "reason": "High frequency (6/10 admissions); oral follow-up analgesic."
#       },
#       {
#         "item": "RINGER LACTATE 500ML INF (BBRAUN)",
#         "analysis": "Balanced crystalloid solution for perioperative fluid replacement.",
#         "reason": "High frequency (6/10 admissions); standard intraoperative fluid."
#       },
#       {
#         "item": "PEHACAIN 2ML INJ",
#         "analysis": "Local anesthetic (lidocaine with epinephrine) for intraoperative pain control.",
#         "reason": "Moderate frequency (5/10 admissions); essential for local infiltration."
#       },
#       {
#         "item": "DEXAMETHASONE 0,5MG TAB",
#         "analysis": "Oral corticosteroid for continued postoperative inflammation control.",
#         "reason": "Moderate frequency (5/10 admissions); follow-up anti-inflammatory."
#       },
#       {
#         "item": "WATER FOR INJ 25ML (OTSU)",
#         "analysis": "Sterile diluent for reconstitution of injectable medications.",
#         "reason": "Moderate frequency (5/10 admissions); necessary for IV drug preparation."
#       },
#       {
#         "item": "SEVOFLURANE 250ML",
#         "analysis": "Inhalational anesthetic for maintenance of general anesthesia.",
#         "reason": "High frequency (5/10 admissions); standard in odontectomy cases."
#       },
#       {
#         "item": "NATRIUM DIKLOFENAK 50MG TAB",
#         "analysis": "NSAID for postoperative pain and inflammation.",
#         "reason": "Moderate frequency (5/10 admissions); alternative to ibuprofen."
#       },
#       {
#         "item": "PARACETAMOL 10MG/ML-100ML INF",
#         "analysis": "IV analgesic and antipyretic for mild to moderate pain.",
#         "reason": "Moderate frequency (5/10 admissions); used when oral route not possible."
#       },
#       {
#         "item": "OTSU-NS NACL 0,9% 500ML INF",
#         "analysis": "Isotonic saline for fluid replacement and drug dilution.",
#         "reason": "Moderate frequency (4/10 admissions); perioperative fluid management."
#       },
#       {
#         "item": "SEDACUM 5MG/5ML INJ",
#         "analysis": "Midazolam-based sedative for premedication or intraoperative sedation.",
#         "reason": "Lower frequency but relevant for anesthesia protocol."
#       },
#       {
#         "item": "SAGESTAM 40MG/ML INJ",
#         "analysis": "Steroid injection for inflammation control.",
#         "reason": "Lower frequency but relevant in some cases for swelling control."
#       },
#       {
#         "item": "EMBALASE",
#         "analysis": "Nutritional supplement to support recovery.",
#         "reason": "Lower frequency but relevant for postoperative nutritional support."
#       }
#     ],
#     "Item Average": 27,
#     "Summary": "The patient is diagnosed with ICD-10 K01.1 (impacted teeth) and ICD-9 23.19 (surgical extraction of tooth), indicating surgical removal of impacted molars under general anesthesia. Historical data from highly similar admissions shows a consistent perioperative regimen including general anesthetics (sevoflurane, propofol, rocuronium, fentanyl), antibiotics (ceftriaxone, cefixime, gentamycin), analgesics (ketorolac, ibuprofen, paracetamol, diclofenac), antiemetics (ondansetron), corticosteroids (dexamethasone), antifibrinolytics (tranexamic acid), gastric protection (omeprazole, esomeprazole), and supportive fluids. The prediction includes high-frequency items and essential lower-frequency drugs to meet the average of 27 items for the 'Drugs' category."
#   },
#   "Medical_Diagnostic": {
#     "predictions": [
#       {
#         "item": "SMALL HISTOPATHOLOGY (<3 CM)",
#         "quantity": 1,
#         "sub_category": "Laboratory"
#       },
#       {
#         "item": "IPD CONSULTATION/VISIT RMO",
#         "quantity": 1,
#         "sub_category": "Consultation and Visit"
#       },
#       {
#         "item": "CONSULTATION IPD (VISIT) _SPECIALIST",
#         "quantity": 1,
#         "sub_category": "Consultation and Visit"
#       },
#       {
#         "item": "IPD CONSULTATION/VISIT II_1 (SUB SPECIALIST / CONSULTANT)",
#         "quantity": 1,
#         "sub_category": "Consultation and Visit"
#       },
#       {
#         "item": "IPD CONSULTATION/VISIT I_1",
#         "quantity": 1,
#         "sub_category": "Consultation and Visit"
#       }
#     ],
#     "references": [
#       -2004234,
#       -3152391,
#       9000007046318,
#       9000007035801,
#       -4167019,
#       -4503356,
#       -4733119
#     ],
#     "reasoning": [
#       {
#         "item": "SMALL HISTOPATHOLOGY (<3 CM)",
#         "sub_category": "Laboratory",
#         "analysis": "Histopathology is performed on excised tissue from impacted tooth surgery to rule out pathology such as cysts or tumors.",
#         "reason": "This laboratory test appears in 7 similar inpatient admissions for impacted teeth with odontectomy, making it a standard diagnostic step."
#       },
#       {
#         "item": "IPD CONSULTATION/VISIT RMO",
#         "sub_category": "Consultation and Visit",
#         "analysis": "Routine daily inpatient visit by the Resident Medical Officer to monitor post-surgical recovery.",
#         "reason": "Highly frequent in similar inpatient admissions, ensuring continuous monitoring and documentation of patient status."
#       },
#       {
#         "item": "CONSULTATION IPD (VISIT) _SPECIALIST",
#         "sub_category": "Consultation and Visit",
#         "analysis": "Specialist consultation by the oral and maxillofacial surgeon for post-operative care and surgical site evaluation.",
#         "reason": "Common in similar cases where specialist follow-up is required during inpatient stay."
#       },
#       {
#         "item": "IPD CONSULTATION/VISIT II_1 (SUB SPECIALIST / CONSULTANT)",
#         "sub_category": "Consultation and Visit",
#         "analysis": "Sub-specialist or consultant review for complex dental surgical cases to ensure optimal recovery.",
#         "reason": "Observed in multiple similar inpatient admissions, especially for surgical dental cases under general anesthesia."
#       },
#       {
#         "item": "IPD CONSULTATION/VISIT I_1",
#         "sub_category": "Consultation and Visit",
#         "analysis": "Initial inpatient consultation to assess the patient's condition and plan post-operative management.",
#         "reason": "Appears in several similar inpatient cases as part of standard admission protocol."
#       }
#     ],
#     "Item Average": 5,
#     "Summary": "The new patient is an inpatient with impacted teeth (K01.1) undergoing odontectomy (23.19) under oral and maxillofacial surgery. Historical inpatient cases with the same diagnosis and procedure consistently included histopathology of excised tissue and multiple levels of inpatient consultations (RMO, specialist, sub-specialist, and initial visit). These items are predicted as they are standard for monitoring, specialist input, and confirming pathology in similar surgical dental cases."
#   },
#   "Treatment_Facility": {
#     "predictions": [
#       {
#         "item": "DOKTER OPERATOR _TABLE _TARIF I _ 2",
#         "quantity": 1,
#         "sub_category": "Surgeon"
#       },
#       {
#         "item": "DOKTER ANESTHESI _TABLE _TARIF I _ 2",
#         "quantity": 1,
#         "sub_category": "Anesthetist"
#       },
#       {
#         "item": "OT CHARGE PER 15 MINUTES",
#         "quantity": 6,
#         "sub_category": "Procedure Room Rental"
#       },
#       {
#         "item": "RECOVERY ROOM",
#         "quantity": 1,
#         "sub_category": "Procedure Room Rental"
#       },
#       {
#         "item": "GENERAL WARD / UMUM",
#         "quantity": 2,
#         "sub_category": "Bed Rental"
#       },
#       {
#         "item": "Oksigen < 6 jam",
#         "quantity": 1,
#         "sub_category": "Care Package"
#       },
#       {
#         "item": "CSSD_SPECIAL SET (INSTRUMENT)",
#         "quantity": 1,
#         "sub_category": "Care Package"
#       }
#     ],
#     "references": [
#       -2004234,
#       -3152391,
#       9000007046318,
#       9000007038123,
#       9000007035801,
#       -4167019,
#       -4503356,
#       9000006952302,
#       -4733119,
#       9000006935505
#     ],
#     "reasoning": [
#       {
#         "item": "DOKTER OPERATOR _TABLE _TARIF I _ 2",
#         "sub_category": "Surgeon",
#         "analysis": "This is the surgeon's professional fee for performing the odontectomy procedure, which is the standard surgical intervention for ICD-9 code 23.19 (other surgical extraction of tooth) in cases of impacted teeth (ICD-10 K01.1).",
#         "reason": "Appears in 9 out of 10 similar admissions, all involving oral and maxillofacial surgery for impacted teeth under general anesthesia."
#       },
#       {
#         "item": "DOKTER ANESTHESI _TABLE _TARIF I _ 2",
#         "sub_category": "Anesthetist",
#         "analysis": "This is the anesthetist's professional fee for administering general anesthesia during the odontectomy procedure.",
#         "reason": "Appears in 9 out of 10 similar admissions; general anesthesia is standard for surgical removal of impacted teeth in inpatient settings."
#       },
#       {
#         "item": "OT CHARGE PER 15 MINUTES",
#         "sub_category": "Procedure Room Rental",
#         "analysis": "Covers the operating theatre usage time, billed in 15-minute increments, for the surgical extraction procedure.",
#         "reason": "Appears in all 10 similar admissions; average usage is approximately 5.8 units, rounded to 6 for prediction."
#       },
#       {
#         "item": "RECOVERY ROOM",
#         "sub_category": "Procedure Room Rental",
#         "analysis": "Covers the use of the recovery room post-surgery for monitoring until the patient regains full consciousness and stability.",
#         "reason": "Appears in all 10 similar admissions; standard for post-general anesthesia recovery."
#       },
#       {
#         "item": "GENERAL WARD / UMUM",
#         "sub_category": "Bed Rental",
#         "analysis": "Covers inpatient bed charges in the general ward for postoperative observation and recovery.",
#         "reason": "Appears in all 10 similar admissions; average stay is 2 days for inpatient odontectomy cases."
#       },
#       {
#         "item": "Oksigen < 6 jam",
#         "sub_category": "Care Package",
#         "analysis": "Short-term oxygen therapy provided postoperatively to support recovery from general anesthesia.",
#         "reason": "Appears in 8 out of 10 similar admissions; standard supportive care after general anesthesia."
#       },
#       {
#         "item": "CSSD_SPECIAL SET (INSTRUMENT)",
#         "sub_category": "Care Package",
#         "analysis": "Sterile surgical instrument set prepared by the Central Sterile Supply Department (CSSD) for odontectomy.",
#         "reason": "Appears in 4 out of 10 similar admissions; essential for surgical extraction procedures, especially in inpatient cases."
#       }
#     ],
#     "Item Average": 7,
#     "Summary": "The new patient is an inpatient with ICD-10 K01.1 (impacted teeth) and ICD-9 23.19 (surgical extraction of tooth), scheduled for odontectomy under general anesthesia by an oral and maxillofacial surgeon. Historical data from 10 highly similar admissions show consistent inclusion of surgeon and anesthetist fees, operating theatre and recovery room charges, general ward bed rental, oxygen therapy, and CSSD instrument set. These items are standard for inpatient surgical management of impacted teeth under BPJS coverage."
#   },
#   "Administrative_Others": {
#     "predictions": [
#       {
#         "item": "PATIENT MONITOR PER DAY",
#         "quantity": 1,
#         "sub_category": "Medical Equipment Rental"
#       },
#       {
#         "item": "ANESTETIIC MACHINE",
#         "quantity": 1,
#         "sub_category": "Medical Equipment Rental"
#       },
#       {
#         "item": "ODONTECTOMY SET",
#         "quantity": 1,
#         "sub_category": "Medical Equipment Rental"
#       },
#       {
#         "item": "SUCTIONING PROCEDURE",
#         "quantity": 1,
#         "sub_category": "Other Service and Charge"
#       },
#       {
#         "item": "STERILIZATION_SPECIAL SET",
#         "quantity": 1,
#         "sub_category": "Other Service and Charge"
#       },
#       {
#         "item": "GOWN PACK",
#         "quantity": 1,
#         "sub_category": "Other Service and Charge"
#       },
#       {
#         "item": "SURGICAL LINEN PACK",
#         "quantity": 1,
#         "sub_category": "Other Service and Charge"
#       }
#     ],
#     "references": [
#       -2004234,
#       -3152391,
#       9000007046318,
#       9000007038123,
#       9000007035801,
#       -4167019,
#       -4503356,
#       9000006952302,
#       -4733119,
#       9000006935505
#     ],
#     "reasoning": [
#       {
#         "item": "PATIENT MONITOR PER DAY",
#         "sub_category": "Medical Equipment Rental",
#         "analysis": "Continuous monitoring of vital signs is standard for inpatients undergoing surgery under general anesthesia, especially in oral and maxillofacial surgery.",
#         "reason": "High-frequency item (10 admissions) and essential for postoperative monitoring in inpatient surgical cases."
#       },
#       {
#         "item": "ANESTETIIC MACHINE",
#         "sub_category": "Medical Equipment Rental",
#         "analysis": "Required for delivering general anesthesia during odontectomy procedures.",
#         "reason": "High-frequency item (9 admissions) and critical for surgical anesthesia delivery."
#       },
#       {
#         "item": "ODONTECTOMY SET",
#         "sub_category": "Medical Equipment Rental",
#         "analysis": "Specialized surgical instrument set for impacted tooth removal.",
#         "reason": "High-frequency item (8 admissions) and directly related to the planned surgical procedure."
#       },
#       {
#         "item": "SUCTIONING PROCEDURE",
#         "sub_category": "Other Service and Charge",
#         "analysis": "Used intraoperatively to maintain a clear surgical field and postoperatively to manage oral secretions.",
#         "reason": "High-frequency item (7 admissions) and standard in oral surgery cases."
#       },
#       {
#         "item": "STERILIZATION_SPECIAL SET",
#         "sub_category": "Other Service and Charge",
#         "analysis": "Sterilization of specialized surgical instruments, including odontectomy and CSSD-related sets.",
#         "reason": "High-frequency item (6 admissions) and mandatory for infection control in surgical cases."
#       },
#       {
#         "item": "GOWN PACK",
#         "sub_category": "Other Service and Charge",
#         "analysis": "Sterile gowning for surgical team to maintain aseptic conditions.",
#         "reason": "High-frequency item (9 admissions) and standard for all surgical procedures."
#       },
#       {
#         "item": "SURGICAL LINEN PACK",
#         "sub_category": "Other Service and Charge",
#         "analysis": "Sterile drapes and linens used to cover the patient and maintain a sterile field during surgery.",
#         "reason": "High-frequency item (5 admissions) and essential for maintaining sterile surgical environment."
#       }
#     ],
#     "Item Average": 7,
#     "Summary": "The new patient is an inpatient undergoing odontectomy for impacted teeth (K01.1, ICD-9 23.19) under general anesthesia. Historical data from highly similar admissions show consistent use of specific medical equipment rentals (patient monitor, anesthetic machine, odontectomy set), procedural services (suctioning, sterilization), and surgical support items (gown pack, surgical linen pack). All selected items are high-frequency across similar cases and essential for safe surgical care and infection control."
#   }
# }
#
#
# --- Tabel Prediksi Akhir ---
#                          Agent Group                                                    Item Name  Quantity                                                    Reasoning
# 0   Consumables_and_Medical_Supplies                                      VIOREX 2% 20ML (REPACK)         1  Appears in all similar admissions (10/10); essential for...
# 1   Consumables_and_Medical_Supplies              MEDIGLOVES STERILE POWDER FREE LATEX 6.5 ONEMED         1  High frequency (10/10 admissions); critical for infectio...
# 2   Consumables_and_Medical_Supplies                SYRINGE WITHOUT NEEDLE LUER LOCK 20ML KANGJIN         1  High frequency (10/10 admissions); standard in dental su...
# 3   Consumables_and_Medical_Supplies                     SUCTION CATH 12CH SHM-SC-12SCC HOSPITECH         1  High frequency (10/10 admissions); essential for maintai...
# 4   Consumables_and_Medical_Supplies              SURFLO IV CATH 18GX1.1/4INCH SR+OX1832C3 TERUMO         1  High frequency (10/10 admissions); required for anesthes...
# 5   Consumables_and_Medical_Supplies  ADULT BACTERIAL VIRAL FILTER WITH HME LUER LOCK PORT (VE...         1  High frequency (9/10 admissions); standard in general an...
# 6   Consumables_and_Medical_Supplies  TRUSYNTH 3-0 90CM ROUND BODIED 26MM VIOLET 10F90DZ26 HEA...         1  High frequency (9/10 admissions); essential for odontect...
# 7   Consumables_and_Medical_Supplies  TRANSPARANT FILM DRESSING 6X7CM WITH NOTCH 1IVD-0607N WI...         1  High frequency (9/10 admissions); used to secure IV line...
# 8   Consumables_and_Medical_Supplies                              INFUSION SET 21GX1.5INCH ONEMED         1  High frequency (9/10 admissions); standard perioperative...
# 9   Consumables_and_Medical_Supplies                             SYRINGE 5ML (22Gx1.5INCH) ONEMED         2  High frequency (9/10 admissions); dosage based on averag...
# 10  Consumables_and_Medical_Supplies                            SYRINGE 10ML (21Gx1.5INCH) ONEMED         2  High frequency (9/10 admissions); quantity based on medi...
# 11  Consumables_and_Medical_Supplies                                         ALCOHOL SWABS ONEMED        10  High frequency (8/10 admissions); quantity standardized ...
# 12  Consumables_and_Medical_Supplies                           APRON PLASTIK LENGAN PENDEK ONEMED         3  High frequency (8/10 admissions); standard PPE in oral s...
# 13  Consumables_and_Medical_Supplies  js/ INSYTE TM IV CATHETER 20GA X 1.16 IN (1,1 X 30MM) 38...         1  High frequency (8/10 admissions); alternative gauge for ...
# 14  Consumables_and_Medical_Supplies           js/ SUCTION CONNECTING TUBE 3.6M 4815000047 ONEMED         1  High frequency (7/10 admissions); essential for maintain...
# 15  Consumables_and_Medical_Supplies                     ECG ELECTRODES BLUESENSOR R-00-S/25 AMBU         3  High frequency (7/10 admissions); quantity based on aver...
# 16  Consumables_and_Medical_Supplies                                      NEEDLE 18Gx1.5MM ONEMED         1  High frequency (7/10 admissions); standard perioperative...
# 17  Consumables_and_Medical_Supplies         GUEDEL AIRWAY 4/90MM STERILE; 900 0090 1; BICAKCILAR         1  High frequency (7/10 admissions); standard in general an...
# 18  Consumables_and_Medical_Supplies              MEDIGLOVES STERILE POWDER FREE LATEX 7.0 ONEMED         1  High frequency (7/10 admissions); size variation for staff.
# 19  Consumables_and_Medical_Supplies                              T-HEMOCEL 5X7,5CM ORC-01 TRITON         1  High frequency (7/10 admissions); essential in oral surg...
# 20  Consumables_and_Medical_Supplies           STERILE SCALPEL BLADES NO. 15 110-115 HEINZ HERENZ         1  High frequency (6/10 admissions); standard for odontectomy.
# 21  Consumables_and_Medical_Supplies                               js/ UNDERPAD 60X90 91711 SENSI         1  High frequency (6/10 admissions); standard in surgical s...
# 22  Consumables_and_Medical_Supplies                            SYRINGE 3ML (23Gx1.25INCH) ONEMED         1  High frequency (6/10 admissions); used for local anesthe...
# 23  Consumables_and_Medical_Supplies                    3WAY STOPCOCK WITH EXTENSION TUBE GP CARE         1  High frequency (6/10 admissions); essential for perioper...
# 24  Consumables_and_Medical_Supplies              MEDIGLOVES STERILE POWDER FREE LATEX 7.5 ONEMED         1  High frequency (6/10 admissions); size variation for staff.
# 25  Consumables_and_Medical_Supplies            js/ INSYTE TM IV CATHETER 22GAx1.00INCH 381223 BD         1  High frequency (5/10 admissions); alternative gauge for ...
# 26  Consumables_and_Medical_Supplies                PD ETT NON KK CUFFED 7.0MM; 104105; PRODEVICE         1  Moderate frequency (5/10 admissions); relevant for gener...
# 27  Consumables_and_Medical_Supplies       KASSA STERILE LD 7.5CM X 7.5CM 16PLY @5S 7165LD ONEMED         3  Moderate frequency (5/10 admissions); essential for oral...
# 28  Consumables_and_Medical_Supplies                SYRINGE WITH NEEDLE 23G LUER LOCK 3ML KANGJIN         1  Moderate frequency (4/10 admissions); relevant for perio...
# 29  Consumables_and_Medical_Supplies                 ETT CUFFED NO.7.0 SPIRAL 55170701 BICAKCILAR         1  Moderate frequency (4/10 admissions); alternative to non...
# 30  Consumables_and_Medical_Supplies                                     TRANSOFIX 4090500 BBRAUN         1  Moderate frequency (4/10 admissions); standard in surgic...
# 31  Consumables_and_Medical_Supplies                                                   HANSAPLAST         3  Moderate frequency (4/10 admissions); used post-IV removal.
# 32  Consumables_and_Medical_Supplies                               PLESTERIN KAIN ELASTIS; ONEMED         3  Moderate frequency (3/10 admissions); relevant for posto...
# 33  Consumables_and_Medical_Supplies                              LYOSTYPT 5 X 8CM 1069152 BBRAUN         1  Lower frequency (2/10 admissions) but clinically relevan...
# 34  Consumables_and_Medical_Supplies        SUCTION CONNECTING TUBE 3.6M PLUS YANKAUER TIP ONEMED         1  Lower frequency (2/10 admissions) but relevant for maint...
# 35  Consumables_and_Medical_Supplies                               SYRINGE 10ML SS+10L2138 TERUMO         1  Lower frequency (2/10 admissions) but relevant for anest...
# 36                             Drugs                                           CEFIXIME 200MG CAP        10  High frequency (10/10 admissions) in similar odontectomy...
# 37                             Drugs                                        CEFTRIAXONE 1GRAM INJ         1  Universal use in similar cases for IV prophylaxis; dosag...
# 38                             Drugs                               js/ FENTANYL 0,05MG/ML-2ML INJ         2  Present in all matched admissions; essential for anesthe...
# 39                             Drugs                                             ROCUM 1% 5ML INJ         1  Used in all similar surgical cases; standard anesthesia ...
# 40                             Drugs                                      ONDANSETRON 4MG/2ML INJ         1  High frequency (10/10 admissions); standard prophylaxis ...
# 41                             Drugs                                          OMEPRAZOLE 20MG CAP        10  High frequency (10/10 admissions); standard perioperativ...
# 42                             Drugs                                 DEXAMETHASONE 5MG/ML-1ML INJ         3    High frequency (9/10 admissions); dosage matches average.
# 43                             Drugs                                RECOFOL N 1% 10MG/ML-20ML INJ         1  High frequency (9/10 admissions); essential for anesthesia.
# 44                             Drugs                                        ESOMEPRAZOLE 40MG INJ         1  High frequency (9/10 admissions); used when oral route n...
# 45                             Drugs                                    KETOROLAC 30MG/ML-1ML INJ         3  High frequency (8/10 admissions); standard non-opioid an...
# 46                             Drugs                                   ATROPINE 0,25MG/ML-1ML INJ         4  High frequency (8/10 admissions); standard anesthesia ad...
# 47                             Drugs                            ASAM TRANEKSAMAT 100MG/ML-5ML INJ         1  High frequency (7/10 admissions); indicated in oral surg...
# 48                             Drugs                       NEOSTIGMINE METHYLSULFATE 0,5MG/ML INJ         4  High frequency (7/10 admissions); standard anesthesia re...
# 49                             Drugs                                 js/ POVIDONE IODINE 60ML SOL         1  High frequency (7/10 admissions); essential for oral sur...
# 50                             Drugs                                   GENTAMYCIN 40MG/ML-2ML INJ         2  High frequency (7/10 admissions); used in combination wi...
# 51                             Drugs                                          IBUPROFEN 400MG TAB        10  High frequency (6/10 admissions); oral follow-up analgesic.
# 52                             Drugs                            RINGER LACTATE 500ML INF (BBRAUN)         2  High frequency (6/10 admissions); standard intraoperativ...
# 53                             Drugs                                             PEHACAIN 2ML INJ         3  Moderate frequency (5/10 admissions); essential for loca...
# 54                             Drugs                                      DEXAMETHASONE 0,5MG TAB        10  Moderate frequency (5/10 admissions); follow-up anti-inf...
# 55                             Drugs                                    WATER FOR INJ 25ML (OTSU)         1  Moderate frequency (5/10 admissions); necessary for IV d...
# 56                             Drugs                                            SEVOFLURANE 250ML        40  High frequency (5/10 admissions); standard in odontectom...
# 57                             Drugs                                  NATRIUM DIKLOFENAK 50MG TAB        10  Moderate frequency (5/10 admissions); alternative to ibu...
# 58                             Drugs                                PARACETAMOL 10MG/ML-100ML INF         1  Moderate frequency (5/10 admissions); used when oral rou...
# 59                             Drugs                                  OTSU-NS NACL 0,9% 500ML INF         1  Moderate frequency (4/10 admissions); perioperative flui...
# 60                             Drugs                                          SEDACUM 5MG/5ML INJ         1        Lower frequency but relevant for anesthesia protocol.
# 61                             Drugs                                         SAGESTAM 40MG/ML INJ         2  Lower frequency but relevant in some cases for swelling ...
# 62                             Drugs                                                     EMBALASE         1  Lower frequency but relevant for postoperative nutrition...
# 63                Medical_Diagnostic                                 SMALL HISTOPATHOLOGY (<3 CM)         1  This laboratory test appears in 7 similar inpatient admi...
# 64                Medical_Diagnostic                                   IPD CONSULTATION/VISIT RMO         1  Highly frequent in similar inpatient admissions, ensurin...
# 65                Medical_Diagnostic                         CONSULTATION IPD (VISIT) _SPECIALIST         1  Common in similar cases where specialist follow-up is re...
# 66                Medical_Diagnostic    IPD CONSULTATION/VISIT II_1 (SUB SPECIALIST / CONSULTANT)         1  Observed in multiple similar inpatient admissions, espec...
# 67                Medical_Diagnostic                                   IPD CONSULTATION/VISIT I_1         1  Appears in several similar inpatient cases as part of st...
# 68                Treatment_Facility                          DOKTER OPERATOR _TABLE _TARIF I _ 2         1  Appears in 9 out of 10 similar admissions, all involving...
# 69                Treatment_Facility                         DOKTER ANESTHESI _TABLE _TARIF I _ 2         1  Appears in 9 out of 10 similar admissions; general anest...
# 70                Treatment_Facility                                     OT CHARGE PER 15 MINUTES         6  Appears in all 10 similar admissions; average usage is a...
# 71                Treatment_Facility                                                RECOVERY ROOM         1  Appears in all 10 similar admissions; standard for post-...
# 72                Treatment_Facility                                          GENERAL WARD / UMUM         2  Appears in all 10 similar admissions; average stay is 2 ...
# 73                Treatment_Facility                                              Oksigen < 6 jam         1  Appears in 8 out of 10 similar admissions; standard supp...
# 74                Treatment_Facility                                CSSD_SPECIAL SET (INSTRUMENT)         1  Appears in 4 out of 10 similar admissions; essential for...
# 75             Administrative_Others                                      PATIENT MONITOR PER DAY         1  High-frequency item (10 admissions) and essential for po...
# 76             Administrative_Others                                           ANESTETIIC MACHINE         1  High-frequency item (9 admissions) and critical for surg...
# 77             Administrative_Others                                              ODONTECTOMY SET         1  High-frequency item (8 admissions) and directly related ...
# 78             Administrative_Others                                         SUCTIONING PROCEDURE         1  High-frequency item (7 admissions) and standard in oral ...
# 79             Administrative_Others                                    STERILIZATION_SPECIAL SET         1  High-frequency item (6 admissions) and mandatory for inf...
# 80             Administrative_Others                                                    GOWN PACK         1  High-frequency item (9 admissions) and standard for all ...
# 81             Administrative_Others                                          SURGICAL LINEN PACK         1  High-frequency item (5 admissions) and essential for mai...
#
#
# --- Memulai Pembersihan Knowledge Base ---
# ✅ File sementara dihapus: data/Other_Service_and_Charge.json
# ✅ File sementara dihapus: data/Drugs.json
# ✅ File sementara dihapus: data/Bed_Rental.json
# ✅ File sementara dihapus: data/Procedure_Room_Rental.json
# ✅ File sementara dihapus: data/Laboratory.json
# ✅ File sementara dihapus: data/Procedure_and_Therapy.json
# ✅ File sementara dihapus: data/Radiology.json
# ✅ File sementara dihapus: data/Other_Items.json
# ✅ File sementara dihapus: data/Diagnostic.json
# ✅ File sementara dihapus: data/Anesthetist.json
# ✅ File sementara dihapus: data/Medical_Equipment_Rental.json
# ✅ File sementara dihapus: data/Administrative_Charge.json
# ✅ File sementara dihapus: data/Checkup_Package.json
# ✅ File sementara dihapus: data/Consultation_and_Visit.json
# ✅ File sementara dihapus: data/Consumables_and_Medical_Supplies.json
# ✅ File sementara dihapus: data/Surgeon.json
# ✅ File sementara dihapus: data/Care_Package.json
# 🎉 Pembersihan file knowledge base selesai.

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

predictions_df.loc[
    predictions_df['Agent Group'] == 'Consumables_and_Medical_Supplies',
    
    ['Item Name', 'Quantity']
]
# Out:
#                                                       Item Name  Quantity
# 0                                       VIOREX 2% 20ML (REPACK)         1
# 1               MEDIGLOVES STERILE POWDER FREE LATEX 6.5 ONEMED         1
# 2                 SYRINGE WITHOUT NEEDLE LUER LOCK 20ML KANGJIN         1
# 3                      SUCTION CATH 12CH SHM-SC-12SCC HOSPITECH         1
# 4               SURFLO IV CATH 18GX1.1/4INCH SR+OX1832C3 TERUMO         1
# 5   ADULT BACTERIAL VIRAL FILTER WITH HME LUER LOCK PORT (VE...         1
# 6   TRUSYNTH 3-0 90CM ROUND BODIED 26MM VIOLET 10F90DZ26 HEA...         1
# 7   TRANSPARANT FILM DRESSING 6X7CM WITH NOTCH 1IVD-0607N WI...         1
# 8                               INFUSION SET 21GX1.5INCH ONEMED         1
# 9                              SYRINGE 5ML (22Gx1.5INCH) ONEMED         2
# 10                            SYRINGE 10ML (21Gx1.5INCH) ONEMED         2
# 11                                         ALCOHOL SWABS ONEMED        10
# 12                           APRON PLASTIK LENGAN PENDEK ONEMED         3
# 13  js/ INSYTE TM IV CATHETER 20GA X 1.16 IN (1,1 X 30MM) 38...         1
# 14           js/ SUCTION CONNECTING TUBE 3.6M 4815000047 ONEMED         1
# 15                     ECG ELECTRODES BLUESENSOR R-00-S/25 AMBU         3
# 16                                      NEEDLE 18Gx1.5MM ONEMED         1
# 17         GUEDEL AIRWAY 4/90MM STERILE; 900 0090 1; BICAKCILAR         1
# 18              MEDIGLOVES STERILE POWDER FREE LATEX 7.0 ONEMED         1
# 19                              T-HEMOCEL 5X7,5CM ORC-01 TRITON         1
# 20           STERILE SCALPEL BLADES NO. 15 110-115 HEINZ HERENZ         1
# 21                               js/ UNDERPAD 60X90 91711 SENSI         1
# 22                            SYRINGE 3ML (23Gx1.25INCH) ONEMED         1
# 23                    3WAY STOPCOCK WITH EXTENSION TUBE GP CARE         1
# 24              MEDIGLOVES STERILE POWDER FREE LATEX 7.5 ONEMED         1
# 25            js/ INSYTE TM IV CATHETER 22GAx1.00INCH 381223 BD         1
# 26                PD ETT NON KK CUFFED 7.0MM; 104105; PRODEVICE         1
# 27       KASSA STERILE LD 7.5CM X 7.5CM 16PLY @5S 7165LD ONEMED         3
# 28                SYRINGE WITH NEEDLE 23G LUER LOCK 3ML KANGJIN         1
# 29                 ETT CUFFED NO.7.0 SPIRAL 55170701 BICAKCILAR         1
# 30                                     TRANSOFIX 4090500 BBRAUN         1
# 31                                                   HANSAPLAST         3
# 32                               PLESTERIN KAIN ELASTIS; ONEMED         3
# 33                              LYOSTYPT 5 X 8CM 1069152 BBRAUN         1
# 34         KASSA STERILE 10CMX10CM 16PLY @10S; 101610LD; ONEMED         1
# 35        SUCTION CONNECTING TUBE 3.6M PLUS YANKAUER TIP ONEMED         1
